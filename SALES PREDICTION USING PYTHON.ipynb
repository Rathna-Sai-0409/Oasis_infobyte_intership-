# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv(r"C:\Users\Kadad\OneDrive\Documents\Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head(20)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13   23.8   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19   69.2   20.5       18.3   11.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
 df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['TV'],y=df['Sales'])
plt.plot([min(df['TV']),max(df['TV'])], [min(df['Sales']),max(df['Sales'])],linestyle="--",color="red",linewidth=2.1)
plt.grid(True)
plt.show()

# %%
 

plt.figure(figsize=(5, 5))
sns.scatterplot(data=df, x=df["Radio"], y=df["Sales"])
plt.plot([min(df["Radio"]), max(df["Radio"])], [min(df["Sales"]), max(df["Sales"])], linestyle='--', color="black", linewidth=2)

plt.title('Scatter Plot of Radio vs. Sales', fontsize=16)
plt.xlabel('Radio', fontsize=14)
plt.ylabel('Sales', fontsize=14)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=df,x=df["Newspaper"],y=df["Sales"])
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(df)
plt.show()

# %%
# Correlation between independent and dependent variable
corr = df.corr()
corr
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
x=df.drop('Sales',axis=1)
(x)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df["Sales"]
(y)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# # Applying the linear_model LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([10.24664397,  7.3067958 ,  7.01313011, 24.0629912 , 11.84538583,
#         6.3623126 , 12.97367539, 15.01392577, 10.95137181, 16.2302401 ,
#        22.94764396,  9.07892877, 10.29830431, 15.372556  , 11.63358138,
#        12.38729183, 18.91996453, 10.72601207, 16.03372676, 17.36589369,
#        23.85225051,  9.51048184, 15.25366204, 12.2528663 ,  5.81346738,
#        15.19998588, 12.12398331, 20.74762723, 13.36651757,  9.16548788,
#        13.0430809 , 21.47977498, 18.01828076, 21.14170908,  6.74096317,
#         5.9527019 ,  7.82515133, 13.21661502, 14.72150697,  6.18172688])

# %%
bias=model.score(x_train,y_train)
bias
# Out:
# 0.9073274552252846

# %%
variance=model.score(x_test,y_test)
variance
# Out:
# 0.8564802143279251

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt

# Assuming you have y_test and y_predictions available

# Create a scatter plot
plt.figure(figsize=(8, 6))  # Set the figure size (adjust as needed)

# Scatter plot of y_test vs. y_predictions
plt.scatter(y_test, y_pred, alpha=0.5)  # Use alpha to adjust point transparency

# Title and axis labels
plt.title('Actual vs. Pred', fontsize=20)
plt.xlabel('Actual (y_test)', fontsize=16)
plt.ylabel('Predicted (y_pred)', fontsize=16)

# Adding a diagonal line for reference (perfect predictions)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)

# Customize plot further (grid, legend, etc.) as needed

# Show the plot
plt.grid()
plt.show()
